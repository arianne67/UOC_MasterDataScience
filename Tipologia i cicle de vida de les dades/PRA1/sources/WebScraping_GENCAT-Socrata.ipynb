# %%
import csv
from classes.WebScraping_class import WebScraping_JSON_CSV

#Exemple recuperació dades JSON amb Pandas
#Portal transparència Generalitat, funciona amb l'API Socrata
oJSON = WebScraping_JSON_CSV("https://analisi.transparenciacatalunya.cat/resource/u5vr-ww79.json","json")
oJSON.df.head(5)
# Out:
#        adre_a  codi  codi_postal   codifarm  codmunicip        municipi  \
# 0  SANT JORDI   128         8692  F08000025        8175       PUIG-REIG
# 1   BISBE POL     9         8350  F08000032        8006   ARENYS DE MAR
# 2    ESGLESIA     9         8350  F08000040        8006   ARENYS DE MAR
# 3  SANT MARTI     9         8358  F08000057        8007  ARENYS DE MUNT
# 4        GRAN    10         8310  F08000064        8009       ARGENTONA
#
#                           nom         nomabs num_via tipus_de_via
# 0  BERTRAN AMBROS, ROSA MARIA  BAIX BERGUEDA      11       CARRER
# 1         ABRIL GARCIA, MARIA  ARENYS DE MAR      72        RIERA
# 2       RIGOLA GARROFE, DOLÇA  ARENYS DE MAR       3        PLAÇA
# 3        MIAS NAVARRO, MIREIA  ARENYS DE MAR      56       RAMBLA
# 4      GUILLEN VIDAL, M NURIA      ARGENTONA      22       CARRER
